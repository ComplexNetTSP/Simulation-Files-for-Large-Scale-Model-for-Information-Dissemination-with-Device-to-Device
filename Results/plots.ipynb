# %%
# %pylab inline
import pickle as p
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
tau = 0.05
pop = 15686986

# %% [markdown]
# ## SIR simulation with an inital infection in the Subprefecture 0

# %%
with open('nolatent/1' + '/I.p', 'rb') as fp:
    Inl = p.load(fp)
with open('nolatent/1' + '/R.p', 'rb') as fp:
    Inl_R = p.load(fp)
with open('nolatent/1' + '/A.p', 'rb') as fp:
    A = p.load(fp)
    
with open('latent/4' + '/I.p', 'rb') as fp:
    Il_mu2 = p.load(fp)
with open('latent/4' + '/EI.p', 'rb') as fp:
    EIl_mu2 = p.load(fp)
with open('latent/4' + '/R.p', 'rb') as fp:
    Il_mu2_R = p.load(fp)
with open('latent/4' + '/ER.p', 'rb') as fp:
    Il_mu2_ER = p.load(fp)
with open('latent/4' + '/ES.p', 'rb') as fp:
    Il_mu2_ES = p.load(fp)

with open('latent/6' + '/I.p', 'rb') as fp:
    Il_mu5 = p.load(fp)   
with open('latent/6' + '/EI.p', 'rb') as fp:
    EIl_mu5 = p.load(fp)
with open('latent/6' + '/R.p', 'rb') as fp:
    Il_mu5_R = p.load(fp)
with open('latent/6' + '/ER.p', 'rb') as fp:
    Il_mu5_ER = p.load(fp)
with open('latent/6' + '/ES.p', 'rb') as fp:
    Il_mu5_ES = p.load(fp)
with open('latent/6' + '/A.p', 'rb') as fp:
    A_mu5 = p.load(fp)
    
with open('nolatent/2' + '/I.p', 'rb') as fp:
    Inl_59 = p.load(fp)
with open('nolatent/2' + '/R.p', 'rb') as fp:
    Inl_59_R = p.load(fp)
with open('nolatent/2' + '/A.p', 'rb') as fp:
    A_59 = p.load(fp)
    
with open('latent/3' + '/I.p', 'rb') as fp:
    Il_mu2_59 = p.load(fp)
with open('latent/3' + '/EI.p', 'rb') as fp:
    EIl_mu2_59 = p.load(fp)
with open('latent/3' + '/R.p', 'rb') as fp:
    Il_mu2_59_R = p.load(fp)
with open('latent/3' + '/ER.p', 'rb') as fp:
    Il_mu2_59_ER = p.load(fp)

with open('latent/9' + '/I.p', 'rb') as fp:
    Il_mu5_59 = p.load(fp)
with open('latent/9' + '/EI.p', 'rb') as fp:
    EIl_mu5_59 = p.load(fp)
with open('latent/9' + '/R.p', 'rb') as fp:
    Il_mu5_59_R = p.load(fp)
with open('latent/9' + '/ER.p', 'rb') as fp:
    Il_mu5_59_ER = p.load(fp)   
with open('latent/9' + '/A.p', 'rb') as fp:
    A_mu5_59 = p.load(fp)    
    
with open('latent/22' + '/I.p', 'rb') as fp:
    Il_mu5_return = p.load(fp)  
with open('latent/22' + '/EI.p', 'rb') as fp:
    EIl_mu5_return = p.load(fp)
with open('latent/22' + '/R.p', 'rb') as fp:
    Il_mu5_return_R = p.load(fp)
with open('latent/22' + '/ER.p', 'rb') as fp:
    Il_mu5_return_ER = p.load(fp)

with open('latent/24' + '/I.p', 'rb') as fp: #23
    Il_mu5_59_return = p.load(fp)  
with open('latent/24' + '/EI.p', 'rb') as fp:
    EIl_mu5_59_return = p.load(fp)
with open('latent/24' + '/R.p', 'rb') as fp:
    Il_mu5_59_return_R = p.load(fp)
with open('latent/24' + '/ER.p', 'rb') as fp:
    Il_mu5_59_return_ER = p.load(fp)

# %%
x = np.linspace(tau,70,len(Inl))

# %%
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes
from mpl_toolkits.axes_grid1.inset_locator import mark_inset
from matplotlib.ticker import MaxNLocator
locator_6 = MaxNLocator(6)
locator_3 = MaxNLocator(3)
locator_2 = MaxNLocator(2)

cmap = cm.jet

rcParams['axes.labelsize'] = 9
rcParams['xtick.labelsize'] = 9
rcParams['ytick.labelsize'] = 9
rcParams['legend.fontsize'] = 9
rcParams['text.usetex'] = True
rcParams['figure.figsize'] = 7.3, 4.2
rcParams['axes.labelweight'] = 'bold'
rcParams['font.weight'] = 'bold'
rcParams['axes.linewidth'] = 0.75    
rcParams['lines.linewidth'] = 1.0

f, axarr = plt.subplots(2, 2,sharex=True)

f.text(0.05, 0.5, 'Fraction of the population', ha='center', va='center', rotation='vertical')
f.text(0.5, 0.04, 'Time (Days)', ha='center', va='center')
axarr[0,0].semilogx(x,np.array(Inl)/pop)
axarr[0,0].semilogx(x,np.array(Il_mu2)/pop)
axarr[0,0].semilogx(x,np.array(Il_mu5)/pop)

#
# Heterogeneous
#
x2 = np.linspace(0.3,70,len(Il_mu5_return))
axarr[0,0].semilogx(x2,np.array(Il_mu5_return)/pop, 'k')

axarr[0,0].set_xlim(0.1,70.0)
axarr[0,0].set_title('Subprefecture Akoboissue')
axarr[0,0].yaxis.set_major_locator(locator_6)
rect = [0.2,0.2,0.7,0.7]
ax1 = f.add_axes([0.14, 0.73, 0.15, 0.15]) # X, Y, width, height
setp(ax1.get_yticklabels(), visible=False)
setp(ax1.get_xticklabels(), visible=False)
#ax1.xaxis.set_major_locator(locator_6)
ax1.semilogx(x,np.array(Il_mu5)/pop, 'r')
#
# Heterogeneous
#
ax1.semilogx(x2,np.array(Il_mu5_return)/pop, 'k')
ax1.set_xlim(2.0,10.0)

y1 = (np.array(Inl)+np.array(Inl_R))/pop
y2 = (np.array(Il_mu2_R)+
      np.array(Il_mu2_ER)+
      np.array(EIl_mu2)+
      np.array(Il_mu2))/pop
y5 = (np.array(EIl_mu5)+
      np.array(Il_mu5)+
      np.array(Il_mu5_ER)+
      np.array(Il_mu5_R))/pop
y6 = (np.array(EIl_mu5_return)+
      np.array(Il_mu5_return)+
      np.array(Il_mu5_return_ER)+
      np.array(Il_mu5_return_R))/pop
axarr[1,0].semilogx(x,y1)
axarr[1,0].semilogx(x,y2)
axarr[1,0].semilogx(x,y5)
#
# Heterogeneous
#
axarr[1,0].semilogx(x2,y6,'k')

axarr[0,1].set_title('Subprefecture Abidjan')
p1, = axarr[0,1].semilogx(x,np.array(Inl_59)/pop)
p2, = axarr[0,1].semilogx(x,np.array(Il_mu2_59)/pop)
p3, = axarr[0,1].semilogx(x,np.array(Il_mu5_59)/pop)
#
# Heterogeneous
#
p4, = axarr[0,1].semilogx(x2,np.array(Il_mu5_59_return)/pop, 'k')

setp( axarr[0,1].get_yticklabels(), visible=False)
axarr[0,1].yaxis.set_major_locator(locator_6)
axarr[0,1].legend([p1,p2,p3,p4], ["No Latent state", "10\% of the pop latent","20\% of the pop latent","20\% of the pop latent and heterogeneous return prob"], bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

y11 = (np.array(Inl_59)+np.array(Inl_59_R))/pop
y22 = (np.array(Il_mu2_59_R)+
      np.array(Il_mu2_59_ER)+
      np.array(EIl_mu2_59)+
      np.array(Il_mu2_59))/pop
y55 = (np.array(EIl_mu5_59)+
      np.array(Il_mu5_59)+
      np.array(Il_mu5_59_ER)+
      np.array(Il_mu5_59_R))/pop
y66 = (np.array(EIl_mu5_59_return)+
      np.array(Il_mu5_59_return)+
      np.array(Il_mu5_59_return_ER)+
      np.array(Il_mu5_59_return_R))/pop
axarr[1,1].semilogx(x,y11)
axarr[1,1].semilogx(x,y22)
axarr[1,1].semilogx(x,y55)
#
# Heterogeneous
#
axarr[1,1].semilogx(x2,y66,'k')
setp( axarr[1,1].get_yticklabels(), visible=False)

# Zoom in 
axins = zoomed_inset_axes(axarr[1,1], 4, loc=6) # zoom = 6
axins.semilogx(x,y11)
axins.semilogx(x,y22)
axins.semilogx(x,y55)
axins.set_xlim(0.8, 1.5)
axins.set_ylim(0.15, 0.25)
#axins.xaxis.set_major_locator(locator_3)

mark_inset(axarr[1,1], axins, loc1=3, loc2=4, fc="none", ec="0.5")
setp(axins.get_yticklabels(), visible=False)

savefig('fig1.pdf')
savefig('fig1.svg')

# %%
with open('latent/16' + '/I.p', 'rb') as fp:
    I_59 = p.load(fp)
with open('latent/15' + '/I.p', 'rb') as fp:
    I_59_R = p.load(fp)
figure()
semilogx(np.array(I_59)/pop, 'r-*')
semilogx(np.array(I_59_R)/pop, 'b')

# %%
# Cell

K1 = 100
K2 = 50
Tau = 2
Ki = np.linspace(-0.8, 0.9, 10)

figure()
plot(Ki, Tau*(K1**Ki)/(K2**Ki))
Ki = -0.5
K2 = np.linspace(50,100, 50)
figure()
plot(K2, Tau*(K1**Ki)/(K2**Ki))

# %%
np.linspace(-0.5, 0.5, 10)
# Out:
# array([-0.5       , -0.38888889, -0.27777778, -0.16666667, -0.05555556,
#         0.05555556,  0.16666667,  0.27777778,  0.38888889,  0.5       ])

# %%
x = np.array([2,2])
print (x*x).sum()
# Out:
# 8

# %%
figure()
plot((np.array(Il_mu2_ER)+np.array(EIl_mu2)+np.array(Il_mu2_ES))/pop)
plot((np.array(Il_mu3_ER)+np.array(EIl_mu3)+np.array(Il_mu3_ES))/pop)
plot((np.array(Il_mu4_ER)+np.array(EIl_mu4)+np.array(Il_mu4_ES))/pop)
plot((np.array(Il_mu5_ER)+np.array(EIl_mu5)+np.array(Il_mu5_ES))/pop)

# %%
dim = A_mu5_59.shape[0]
f, axarr = subplots(2, sharex=True)
for i in xrange(dim):
    axarr[0].loglog(x,A_mu5_59[i, :], alpha=0.15, lw=1)
for i in xrange(dim):
    axarr[1].loglog(x,A_mu5[i, :], alpha=0.15, lw=1)
axarr[0].set_xlim(0.1,70.0)
axarr[0].set_title('Subprefecture Abidjan')
axarr[1].set_title('Subprefecture Akoboissue')

# %%
f, axarr = plt.subplots(2, 2,sharex=True)

f.text(0.05, 0.5, 'Infected', ha='center', va='center', rotation='vertical')
f.text(0.5, 0.04, 'Time (Days)', ha='center', va='center')

dim = A.shape[0]
for i in xrange(dim):
    axarr[0,0].loglog(x,A[i, :], alpha=0.15, lw=1)
axarr[0,0].set_xlim(0.1,70.0)
axarr[0,0].set_title('Subprefecture Akoboissue')

axarr[1,0].loglog(x,np.array(Inl),'r')
axarr[1,0].set_ylim(1,pop)

dim = A_59.shape[0]
axarr[0,1].set_title('Subprefecture Abidjan')
for i in xrange(dim):
    axarr[0,1].loglog(x,A_59[i, :], alpha=0.15, lw=1)
setp(axarr[0,1].get_yticklabels(), visible=False)

axarr[1,1].loglog(x,np.array(Inl_59),'r')
axarr[1,1].set_ylim(1,pop)
setp(axarr[1,1].get_yticklabels(), visible=False)
savefig('fig2.pdf')
savefig('fig2.svg')

# %%
with open('../Transitions/degree.p', 'rb') as fp:
    degree = p.load(fp)

# %%
print degree
# Out:
# [40, 50, 43, 100, 84, 56, 46, 71, 56, 142, 106, 60, 126, 39, 34, 74, 51, 112, 46, 52, 109, 172, 86, 158, 126, 140, 104, 113, 105, 36, 84, 0, 71, 36, 32, 29, 48, 0, 213, 102, 104, 73, 80, 138, 33, 110, 49, 91, 0, 104, 0, 159, 94, 82, 81, 136, 72, 222, 94, 236, 160, 37, 189, 197, 88, 160, 180, 111, 204, 82, 52, 0, 67, 51, 157, 46, 86, 66, 81, 37, 0, 91, 0, 110, 63, 52, 0, 0, 171, 57, 69, 56, 47, 67, 48, 95, 78, 0, 42, 73, 96, 46, 70, 54, 0, 125, 47, 139, 49, 91, 0, 0, 81, 39, 68, 138, 182, 126, 78, 68, 107, 193, 161, 127, 83, 128, 48, 30, 31, 55, 39, 33, 63, 70, 0, 0, 41, 200, 99, 143, 120, 138, 147, 200, 87, 151, 43, 121, 88, 172, 130, 67, 106, 155, 73, 76, 29, 65, 77, 96, 18, 52, 35, 51, 160, 123, 148, 111, 87, 57, 101, 131, 163, 130, 105, 33, 42, 106, 89, 34, 64, 181, 101, 79, 126, 128, 158, 69, 59, 135, 66, 147, 61, 95, 25, 91, 82, 152, 65, 128, 55, 42, 37, 53, 76, 33, 68, 45, 81, 45, 81, 110, 55, 44, 31, 47, 24, 50, 39, 56, 0, 31, 66, 42, 100, 40, 53, 86, 98, 44, 55, 100, 126, 43,
# ...

# %%
print degree[59]
# Out:
# 236

# %%
import numpy
kmean = np.mean(degree)
Khi = -0.5
rate = 1./0.5

# %%
1./((1./rate)*(50**Khi)/(kmean**Khi))
# Out:
# 1.5553168735798917

# %%
kmean
# Out:
# 82.678431372549014
