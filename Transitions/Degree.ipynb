# %%
import pickle as p
import numpy as np
import igraph as ig

# %%
with open('transitionprob.p', 'rb') as fp:
    T = p.load(fp)

# %%
G = ig.Graph.Adjacency(np.array(T).tolist(),mode=ig.ADJ_DIRECTED)

# %%
ig.summary(G)
# Out:
# IGRAPH D--- 255 738506228 --

# %%
G.simplify(combine_edges=dict(weight="sum"))

# %%
ig.summary(G)
# Out:
# IGRAPH D-W- 255 21083 --
# + attr: weight (e)

# %%
k = G.strength(w
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-d6c844912e69> in <module>()
# ----> 1 k = G.strenght(mode='in')
#
# AttributeError: 'Graph' object has no attribute 'strenght'

# %%
with open('degree.p', 'w') as degree:
    p.dump(k,degree)

# %%
with open('degree.p', "rb") as pickleFile:
    k = p.load(pickleFile)

# %%
k
# Out:
# [40,
#  50,
#  43,
#  100,
#  84,
#  56,
#  46,
#  71,
#  56,
#  142,
#  106,
#  60,
#  126,
#  39,
#  34,
#  74,
#  51,
#  112,
#  46,
#  52,
#  109,
#  172,
#  86,
#  158,
#  126,
#  140,
#  104,
#  113,
#  105,
#  36,
#  84,
#  0,
#  71,
#  36,
#  32,
#  29,
#  48,
#  0,
#  213,
#  102,
#  104,
#  73,
#  80,
#  138,
#  33,
#  110,
#  49,
#  91,
#  0,
#  104,
#  0,
#  159,
#  94,
#  82,
#  81,
#  136,
#  72,
#  222,
#  94,
#  236,
#  160,
#  37,
#  189,
#  197,
#  88,
#  160,
#  180,
#  111,
#  204,
#  82,
#  52,
#  0,
#  67,
#  51,
#  157,
#  46,
#  86,
#  66,
#  81,
#  37,
#  0,
#  91,
#  0,
#  110,
#  63,
#  52,
#  0,
#  0,
#  171,
#  57,
#  69,
#  56,
#  47,
#  67,
#  48,
#  95,
#  78,
#  0,
#  42,
#  73,
#  96,
#  46,
#  70,
#  54,
#  0,
#  125,
#  47,
#  139,
#  49,
#  91,
#  0,
#  0,
#  81,
#  39,
#  68,
#  138,
#  182,
#  126,
#  78,
#  68,
#  107,
#  193,
#  161,
#  127,
#  83,
#  128,
#  48,
#  30,
#  31,
#  55,
#  39,
#  33,
#  63,
#  70,
#  0,
#  0,
#  41,
#  200,
# ...
